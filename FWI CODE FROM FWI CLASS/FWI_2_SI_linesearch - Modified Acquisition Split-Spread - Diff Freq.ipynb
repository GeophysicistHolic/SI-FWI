# %%
import numpy as np
# %matplotlib inline

from devito import configuration
configuration['log-level'] = 'WARNING'

# %%
import scipy.io as sio
from scipy import signal
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from scipy.signal import convolve2d
from scipy.signal import correlate2d
from scipy.signal import fftconvolve
from scipy.signal import convolve
from scipy.signal import correlate

# Contoh membaca file .mat
data = sio.loadmat("BG450_model.mat")
print(data.keys())
# Misalkan velocity model ada di key tertentu, misalnya 'velocity_model':
vp = data['v'].T[100:300]
#vp0 = np.loadtxt('Vp0 model Padded.txt')
#vp0 = (vp0.T)/1000
vp0 = gaussian_filter(vp, 10) #velocity model intial

print(np.min(vp0))
print(np.max(vp0))

vp0.shape
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'v', 'n', 'd', 'o'])
# 1.4912071034812064
# 4.304304063189347
# (200, 205)

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Thu May 22 10:15:50 2014',
#  '__version__': '1.0',
#  '__globals__': [],
#  'v': array([[1.46356058, 1.46638119, 1.48230541, ..., 1.49039567, 1.46701777,
#          1.45383   ],
#         [1.46647811, 1.47416615, 1.48770535, ..., 1.49200451, 1.47077906,
#          1.45204437],
#         [1.45675921, 1.47178292, 1.48595953, ..., 1.49092162, 1.46984661,
#          1.44722259],
#         ...,
#         [4.09731007, 4.09630251, 4.09983778, ..., 3.99882603, 3.98956394,
#          3.98412228],
#         [4.13336897, 4.13244724, 4.13520861, ..., 4.06025696, 4.04679441,
#          4.03740788],
#         [4.15405846, 4.15371513, 4.15621567, ..., 4.11098623, 4.09505844,
#          4.0832634 ]]),
#  'n': array([[205, 451]], dtype=uint16),
#  'd': array([[10, 10]], dtype=uint8),
#  'o': array([[0, 0]], dtype=uint8)}

# %%
nshots = 11  # Number of shots to create gradient from
nreceivers = 120  # Number of receiver locations per shot 
fwi_iterations = 5  # Number of outer FWI iterations

# %%
#NBVAL_IGNORE_OUTPUT
from examples.seismic import Model, plot_velocity, plot_perturbation, Receiver

# Define a physical size
shape = (vp0.shape)  # Number of grid point (nx, nz)
spacing = (10, 10)  # Grid spacing in m. The domain size is now 1km by 1km
origin = (0.,0.)  # What is the location of the top left corner. This is necessary to define
nboundary = 80

model = Model(vp=vp, origin=origin, shape=shape, spacing=spacing,
              space_order=2, nbl=nboundary, bcs="damp")

model0 = Model(vp=vp0, origin=origin, shape=shape, spacing=spacing,
              space_order=2, nbl=nboundary, bcs="damp", grid = model.grid)

plot_velocity(model)
plot_velocity(model0)
plot_perturbation(model0, model)

# %%
#NBVAL_IGNORE_OUTPUT
# Define acquisition geometry: source
from examples.seismic import AcquisitionGeometry, TimeAxis, RickerSource, PointSource, WaveletSource

t0 = 0.
tn = 1600. 
dt = model.critical_dt
time = TimeAxis(start=t0, stop=tn, step=dt)


f0 = 0.010

# First, position source centrally in all dimensions, then set depth
src_coordinates = np.empty((nshots, 2))
src_coordinates[:, 0] = np.linspace(605, 1405, nshots)
src_coordinates[:, 1] = 20.  # Depth is 20m

# %%
geometrys = []

for i in range(nshots):
    # Define acquisition geometry: receivers

    # Initialize receivers for synthetic and imaging data
    rec_coordinates = np.empty((nreceivers, 2))
    rec_coordinates[:, 0] = np.linspace(10+(i*80), 1200+(i*80), nreceivers)
    rec_coordinates[:, 1] = 20.  # Depth is 20m

    # Geometry
    geometry = AcquisitionGeometry(model, rec_coordinates, src_coordinates, t0, tn, f0=f0, src_type='Ricker')
    geometrys.append(geometry)
print(geometrys[0].time_axis)
# Out:
# TimeAxis: start=0, stop=1600.5, step=1.297, num=1235

# %%
srct = []

for i in range(nshots):
    src = RickerSource(name='src', grid=model0.grid, f0=f0, time_range=time)
    # First, position source centrally in all dimensions, then set depth
    src.coordinates.data[0, :] = src_coordinates[i, 0]
    src.coordinates.data[0, -1] = 20.  # Depth is 20m
    #src.data[:] *= -1
    srct.append(src)
srct[0].show()
srct[0].data.shape
# Out:
# (1235, 1)

# %%
t = np.arange(t0, tn+dt, (dt))
t = t/1000
f0z = f0*1000
t0 = (1/f0z)
st = (1 - (2*(np.pi**2)*(f0z**2)*(t-t0)**2))*(np.exp(-1*(np.pi**2)*(f0z**2)*(t-t0)**2))

wavelet = st

angle = 90
shifted = np.real(np.exp(1j*np.radians(angle)) * signal.hilbert(wavelet))
shifted = np.array([shifted])
shiftedT = shifted.T

srcs = []

for i in range(nshots):
    src = RickerSource(name='src', grid=model0.grid, f0=f0, time_range=time)
    # First, position source centrally in all dimensions, then set depth
    src.coordinates.data[0, :] = src_coordinates[i, 0]
    src.coordinates.data[0, -1] = 20.  # Depth is 20m
    src.data[:] = shiftedT
    src.data[1000:] = 0
    srcs.append(src)
srcs[0].show()
srcs[0].data.shape
# Out:
# (1235, 1)

# %%
t = np.arange(t0, tn+dt, (dt))
t = t/1000
f0z = 4
t0 = (1/5)
st = (1 - (2*(np.pi**2)*(f0z**2)*(t-t0)**2))*(np.exp(-1*(np.pi**2)*(f0z**2)*(t-t0)**2))

wavelet = st

angle = 90
shifted = np.real(np.exp(1j*np.radians(angle)) * signal.hilbert(wavelet))
shifted = np.array([shifted])
shiftedT = shifted.T

srcs2 = []

for i in range(nshots):
    src = RickerSource(name='src', grid=model0.grid, f0=f0, time_range=time)
    # First, position source centrally in all dimensions, then set depth
    src.coordinates.data[0, :] = src_coordinates[i, 0]
    src.coordinates.data[0, -1] = 20.  # Depth is 20m
    src.data[:] = shiftedT
    src.data[1000:] = 0
    srcs2.append(src)
srcs2[0].show()
srcs2[0].data.shape
# Out:
# (1235, 1)

# %%
#NBVAL_IGNORE_OUTPUT
# Plot acquisition geometry
plot_velocity(model, source=geometrys[0].src_positions,
              receiver=geometrys[0].rec_positions)

# %%
# Mencari indeks geophone terdekat untuk setiap shot
nearest_indices = []
i=0
for shot in geometry.src_positions:
    distances = np.linalg.norm(geometrys[i].rec_positions - shot, axis=1)  # Hitung jarak Euclidean
    nearest_index = np.argmin(distances)  # Cari indeks dengan jarak minimum
    nearest_indices.append(nearest_index)
    i+=1

# %%
print(nearest_indices)
# Out:
# [np.int64(59), np.int64(59), np.int64(59), np.int64(59), np.int64(59), np.int64(59), np.int64(59), np.int64(59), np.int64(59), np.int64(59), np.int64(59)]

# %%
from devito import Eq, Operator

# Computes the residual between observed and synthetic data into the residual
def compute_residual(residual, dobs, dsyn, kg):
    if residual.grid.distributor.is_parallel:
        # If we run with MPI, we have to compute the residual via an operator
        # First make sure we can take the difference and that receivers are at the 
        # same position
        assert np.allclose(dobs.coordinates.data[:], dsyn.coordinates.data)
        assert np.allclose(residual.coordinates.data[:], dsyn.coordinates.data)
        # Create a difference operator
        diff_eq = Eq(residual, dsyn.subs({dsyn.dimensions[-1]: residual.dimensions[-1]}) -
                               dobs.subs({dobs.dimensions[-1]: residual.dimensions[-1]}))
        Operator(diff_eq)()
    else:
        # Data ukuran (1920 x 120)
        data_1 = dsyn.data[:]
        data_2 = dobs.data[:]

        # Data ukuran (1920 x 120)
        

        # Pastikan data_2 menjadi array 1D untuk keperluan konvolusi
        filter_data1 = dobs.data[:,kg]
        filter_data2 = dsyn.data[:,kg]


        for i in range(residual.data.shape[1]):
            # Panjang data asli
            len_data1 = len(data_1)

            # Panjang hasil korelasi
            len_full = len(convolve(filter_data1, data_1[:, i], mode='full'))

            # Indeks untuk mengambil nilai tengah
            start = (len_full - len_data1) // 2
            end = start + len_data1
            
            residual.data[:, i] = convolve(data_1[:, i], filter_data1, mode='full')[:len_data1] - convolve(data_2[:, i], filter_data2, mode='full')[:len_data1]
            
         # Data berukuran (1920 x 1)
        
        data_1 = dobs.data[:,kg]

        # Data berukuran (1920 x 120)
        data_2 = residual.data[:]    
        # Menyimpan hasil cross-correlation
        cross_correlations = []
        cross_correlations2 = []
        len_data = len(data_1)
        # Lakukan cross-correlation untuk setiap kolom di data_2
        for i in range(data_2.shape[1]):
            result = correlate(data_2[:, i], data_1, mode='full')[len_data-1:]
            result2 = correlate(data_2[:,i], dobs.data[:,i], mode='full')[len_data-1:]
            cross_correlations.append(result)
            cross_correlations2.append(result2)
        residual.data[:] = np.array(cross_correlations).T
        
        cross_correlations2 = np.array(cross_correlations2)
        tracekg = np.sum(cross_correlations2, axis=0)
        
        residual.data[:, kg] = (tracekg/120)
        
        
        #residual.data[:] = ((residual.data[:] - residual.data[:].min())/(residual.data[:].max()-residual.data[:].min()))*((dobs.data[:].max()-dobs.data.min())+dobs.data.min())
    return residual

# %%
def misfit(vp_in):
    objective = 0.
    for i in range(nshots):
        # Compute synthetic data with forward operator 
        from examples.seismic.acoustic import AcousticWaveSolver

        solver = AcousticWaveSolver(model, geometrys[i], space_order=2)
        
        # Create placeholders for the data residual and data
        residual = Receiver(name='residual', grid=model0.grid,
                            time_range=geometrys[i].time_axis, 
                            coordinates=geometrys[i].rec_positions)
        d_obs = Receiver(name='d_obs', grid=model.grid,
                         time_range=geometrys[i].time_axis, 
                         coordinates=geometrys[i].rec_positions)
        d_syn = Receiver(name='d_syn', grid=model0.grid,
                        time_range=geometrys[i].time_axis, 
                        coordinates=geometrys[i].rec_positions)
        # Update source location
        #geometry.src_positions[0, :] = src_coordinates[i, :]

        # Generate synthetic data from true model
        _, _, _ = solver.forward(vp=model.vp, src=srcs[i], rec=d_obs)

        # Compute smooth data and full forward wavefield u0
        _, _, _ = solver.forward(vp=vp_in.vp, src=srcs2[i], rec=d_syn)

        # Compute gradient from data residual and update objective function 
        compute_residual(residual, d_obs, d_syn, nearest_indices[i])
        objective += 0.5*norm(residual)**2
    return objective

# %%
def linesearch(a, b, l, vp_in, ff,  g):
    from copy import deepcopy
    from devito import Function, TimeFunction, norm
    vp2 = deepcopy(vp_in)
    vp2.vp.data[:] = vp_in.vp.data[:] + l*(g.data[:]/1000)
    gnorm = a*l*norm(g)
    ff2 = misfit(vp2)
    ni = 1
    while (ff2 > ff - gnorm):
        l = b*l
        vp2.vp.data[:] = vp_in.vp.data[:] + l*(g.data[:]/1000)
        ff2 = misfit(vp2)
        gnorm = a*l*norm(g)
        print(ni)
        ni+=1
        if l < 1e-5:
            break
    return l

# %%
# Create FWI gradient kernel 
from devito import Function, TimeFunction, norm
from examples.seismic import Receiver, plot_shotrecord

import scipy
def fwi_gradient(vp_in):    
    # Create symbols to hold the gradient
    grad = Function(name="grad", grid=model.grid)
    
    objective = 0.
    for i in range(nshots):
        # Compute synthetic data with forward operator 
        from examples.seismic.acoustic import AcousticWaveSolver

        solver = AcousticWaveSolver(model, geometrys[i], space_order=2)
        
        # Create placeholders for the data residual and data
        residual = Receiver(name='residual', grid=model.grid,
                            time_range=geometrys[i].time_axis, 
                            coordinates=geometrys[i].rec_positions)
        d_obs = Receiver(name='d_obs', grid=model.grid,
                         time_range=geometrys[i].time_axis, 
                         coordinates=geometrys[i].rec_positions)
        d_syn = Receiver(name='d_syn', grid=model.grid,
                        time_range=geometrys[i].time_axis, 
                        coordinates=geometrys[i].rec_positions)

        
        # Update source location
        #geometry.src_positions[0, :] = src_coordinates[i, :]

        # Generate synthetic data from true model
        _, _, _ = solver.forward(vp=model.vp, src=srcs[i], rec=d_obs)

        # Compute smooth data and full forward wavefield u0
        _, u0, _ = solver.forward(vp=vp_in, save=True, src=srcs2[i], rec=d_syn)
        
        #plot_shotrecord(d_syn.data[:], model0, t0,tn)
        # Compute gradient from data residual and update objective function 
        compute_residual(residual, d_obs, d_syn, nearest_indices[i])
        
        #plot_shotrecord(residual.data, model, t0, tn)
        
        objective += .5*norm(residual)**2
        
        plot_shotrecord(residual.data, model, t0, tn)
        solver.gradient(rec=residual, u=u0, vp=vp_in, grad=grad)
        

        
        
    gradNormalized = Function(name="gradNormalized", grid=model.grid)
    grad.data[:] *= watermute.data[:]
    #grad.data[:] *= modelpadmute.data[:]
    #Normalisasi ke rentang [-1, 1]
    gradNormalized.data[:] = (grad.data)/np.abs(grad.data[:]).max()
    
        

    return objective, gradNormalized

# %%
waterheight = 24
watermute = Function(name="watermute", grid=model.grid)
watermute.data[:,nboundary+waterheight:] += 1

# %%
modelpad = 30
modelpadmute = Function(name="modelpadmute", grid=model.grid)
modelpadmute.data[nboundary+modelpad:,:] += 1
modelpadmute.data[280-(nboundary+modelpad):280,:] = 0

# %%
modeli =[]
misfiti = []
gradi = []

update_model = Model(vp=vp0, origin=origin, shape=shape, spacing=spacing,
              space_order=2, nbl=nboundary, bcs="damp", grid = model.grid)
#plot_velocity(update_model)

modeli.append(update_model)

fwi_iterations = 30  # Number of outer FWI iteration
fwi_index = 0
for i in range(fwi_iterations):
    ff, update = fwi_gradient(update_model.vp)

    misfiti.append(ff)
    gradi.append(update)
    
    print(f"iterasi ke-{i} : {ff}")
    
    a = 0.25
    b = 0.5
    L = 100

    L = linesearch(a, b, L, update_model, ff,  update)

    
    update_model.vp.data[:] += (L*update.data[:]/1000)
    
    # Threshold kecepatan
    threshold = 5.672030575879816

    # Mengatur nilai yang lebih besar dari threshold menjadi nilai threshold
    update_model.vp.data[update_model.vp.data > threshold] = threshold
    
    
    modeli.append(update_model)
    
    if i >= 2 :
        if (np.abs(ff-misfiti[i-1]))<1e-3:
            break
    fwi_index+=1

ff, update = fwi_gradient(update_model.vp)
misfiti.append(ff)
gradi.append(update)

print(f"iterasi ke-{fwi_index} : {ff}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/tools/memoization.py:90, in memoized_meth.__call__(self, *args, **kw)
#      89 try:
# ---> 90     res = cache[key]
#      91 except KeyError:
#
# KeyError: (<function AcousticWaveSolver.op_fwd at 0x7f362ce47400>, (True,), frozenset())
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 14
#      12 fwi_index = 0
#      13 for i in range(fwi_iterations):
# ---> 14     ff, update = fwi_gradient(update_model.vp)
#      16     misfiti.append(ff)
#      17     gradi.append(update)
#
# Cell In[30], line 36, in fwi_gradient(vp_in)
#      33 _, _, _ = solver.forward(vp=model.vp, src=srcs[i], rec=d_obs)
#      35 # Compute smooth data and full forward wavefield u0
# ---> 36 _, u0, _ = solver.forward(vp=vp_in, save=True, src=srcs2[i], rec=d_syn)
#      38 #plot_shotrecord(d_syn.data[:], model0, t0,tn)
#      39 # Compute gradient from data residual and update objective function
#      40 compute_residual(residual, d_obs, d_syn, nearest_indices[i])
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/examples/seismic/acoustic/wavesolver.py:113, in AcousticWaveSolver.forward(self, src, rec, u, model, save, **kwargs)
#     110 kwargs.update(model.physical_params(**kwargs))
#     112 # Execute operator and return wavefield and receiver data
# --> 113 summary = self.op_fwd(save).apply(src=src, rec=rec, u=u,
#     114                                   dt=kwargs.pop('dt', self.dt), **kwargs)
#     116 return rec, u, summary
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/tools/memoization.py:92, in memoized_meth.__call__(self, *args, **kw)
#      90     res = cache[key]
#      91 except KeyError:
# ---> 92     res = cache[key] = self.func(*args, **kw)
#      93 return res
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/examples/seismic/acoustic/wavesolver.py:49, in AcousticWaveSolver.op_fwd(self, save)
#      46 @memoized_meth
#      47 def op_fwd(self, save=None):
#      48     """Cached operator for forward runs with buffered wavefield"""
# ---> 49     return ForwardOperator(self.model, save=save, geometry=self.geometry,
#      50                            kernel=self.kernel, space_order=self.space_order,
#      51                            **self._kwargs)
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/examples/seismic/acoustic/operators.py:149, in ForwardOperator(model, geometry, space_order, save, kernel, **kwargs)
#     146 rec_term = rec.interpolate(expr=u)
#     148 # Substitute spacing terms to reduce flops
# --> 149 return Operator(eqn + src_term + rec_term, subs=model.spacing_map,
#     150                 name='Forward', **kwargs)
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/operator/operator.py:165, in Operator.__new__(cls, expressions, **kwargs)
#     163 # Lower to a JIT-compilable object
#     164 with timed_region('op-compile') as r:
# --> 165     op = cls._build(expressions, **kwargs)
#     166 op._profiler.py_timers.update(r.timings)
#     168 # Emit info about how long it took to perform the lowering
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/operator/operator.py:197, in Operator._build(cls, expressions, **kwargs)
#     194 profiler = create_profile('timers')
#     196 # Lower the input expressions into an IET
# --> 197 irs, byproduct = cls._lower(expressions, profiler=profiler, **kwargs)
#     199 # Make it an actual Operator
#     200 op = Callable.__new__(cls, **irs.iet.args)
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/operator/operator.py:271, in Operator._lower(cls, expressions, **kwargs)
#     268 expressions = cls._lower_exprs(expressions, **kwargs)
#     270 # [LoweredEq] -> [Clusters]
# --> 271 clusters = cls._lower_clusters(expressions, **kwargs)
#     273 # [Clusters] -> ScheduleTree
#     274 stree = cls._lower_stree(clusters, **kwargs)
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/tools/timing.py:76, in timed_pass.__call__(self, *args, **kwargs)
#      73 stack.append(frame)
#      75 tic = time()
# ---> 76 retval = self.func(*args, **kwargs)
#      77 toc = time()
#      79 for f in stack:
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/operator/operator.py:380, in Operator._lower_clusters(cls, expressions, profiler, **kwargs)
#     377 # Operation count before specialization
#     378 init_ops = sum(estimate_cost(c.exprs) for c in clusters if c.is_dense)
# --> 380 clusters = cls._specialize_clusters(clusters, **kwargs)
#     382 # Operation count after specialization
#     383 final_ops = sum(estimate_cost(c.exprs) for c in clusters if c.is_dense)
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/tools/timing.py:76, in timed_pass.__call__(self, *args, **kwargs)
#      73 stack.append(frame)
#      75 tic = time()
# ---> 76 retval = self.func(*args, **kwargs)
#      77 toc = time()
#      79 for f in stack:
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/core/cpu.py:159, in Cpu64AdvOperator._specialize_clusters(cls, clusters, **kwargs)
#     156 sregistry = kwargs['sregistry']
#     158 # Toposort+Fusion (the former to expose more fusion opportunities)
# --> 159 clusters = fuse(clusters, toposort=True)
#     161 # Hoist and optimize Dimension-invariant sub-expressions
#     162 clusters = cire(clusters, 'invariants', sregistry, options, platform)
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/tools/timing.py:76, in timed_pass.__call__(self, *args, **kwargs)
#      73 stack.append(frame)
#      75 tic = time()
# ---> 76 retval = self.func(*args, **kwargs)
#      77 toc = time()
#      79 for f in stack:
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/passes/clusters/misc.py:389, in fuse(clusters, toposort, options)
#     377 """
#     378 Clusters fusion.
#     379
#    (...)
#     386 `toposort=True`.
#     387 """
#     388 if toposort != 'maximal':
# --> 389     return Fusion(toposort, options).process(clusters)
#     391 nxt = clusters
#     392 while True:
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/passes/clusters/misc.py:122, in Fusion.process(self, clusters)
#     120 def process(self, clusters):
#     121     cgroups = [ClusterGroup(c, c.ispace) for c in clusters]
# --> 122     cgroups = self._process_fdta(cgroups, 1)
#     123     clusters = ClusterGroup.concatenate(*cgroups)
#     124     return clusters
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/ir/clusters/visitors.py:89, in Queue._process_fdta(self, clusters, level, prefix, **kwargs)
#      86         processed.extend(list(g))
#      87     else:
#      88         # Recursion
# ---> 89         processed.extend(self._process_fdta(list(g), level + 1, pfx, **kwargs))
#      91 # Apply callback
#      92 processed = self.callback(processed, prefix, **kwargs)
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/ir/clusters/visitors.py:92, in Queue._process_fdta(self, clusters, level, prefix, **kwargs)
#      89         processed.extend(self._process_fdta(list(g), level + 1, pfx, **kwargs))
#      91 # Apply callback
# ---> 92 processed = self.callback(processed, prefix, **kwargs)
#      94 return processed
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/passes/clusters/misc.py:155, in Fusion.callback(self, cgroups, prefix)
#     152 # Maximize effectiveness of topo-sorting at next stage by only
#     153 # grouping together Clusters characterized by data dependencies
#     154 if self.toposort and prefix:
# --> 155     dag = self._build_dag(processed, prefix)
#     156     mapper = dag.connected_components(enumerated=True)
#     157     groups = groupby(processed, key=mapper.get)
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/passes/clusters/misc.py:350, in Fusion._build_dag(self, cgroups, prefix)
#     344 scope = Scope(exprs=cg0.exprs + cg1.exprs, rules=is_cross)
#     346 # Anti-dependences along `prefix` break the execution flow
#     347 # (intuitively, "the loop nests are to be kept separated")
#     348 # * All ClusterGroups between `cg0` and `cg1` must precede `cg1`
#     349 # * All ClusterGroups after `cg1` cannot precede `cg1`
# --> 350 if any(i.cause & prefix for i in scope.d_anti_gen()):
#     351     for cg2 in cgroups[n:cgroups.index(cg1)]:
#     352         dag.add_edge(cg2, cg1)
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/passes/clusters/misc.py:350, in <genexpr>(.0)
#     344 scope = Scope(exprs=cg0.exprs + cg1.exprs, rules=is_cross)
#     346 # Anti-dependences along `prefix` break the execution flow
#     347 # (intuitively, "the loop nests are to be kept separated")
#     348 # * All ClusterGroups between `cg0` and `cg1` must precede `cg1`
#     349 # * All ClusterGroups after `cg1` cannot precede `cg1`
# --> 350 if any(i.cause & prefix for i in scope.d_anti_gen()):
#     351     for cg2 in cgroups[n:cgroups.index(cg1)]:
#     352         dag.add_edge(cg2, cg1)
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/ir/support/basic.py:1092, in Scope.d_anti_gen(self)
#    1090 for k, v in self.writes.items():
#    1091     for w in v:
# -> 1092         for r in self.reads_smart_gen(k):
#    1093             if any(not rule(r, w) for rule in self.rules):
#    1094                 continue
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/ir/support/basic.py:978, in Scope.reads_smart_gen(self, f)
#     975                 yield TimedAccess(j, i.mode, i.timestamp, i.ispace)
#     977 else:
# --> 978     for i in self.reads_gen():
#     979         if f is i.function:
#     980             yield i
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/ir/support/basic.py:889, in Scope.reads_explicit_gen(self)
#     887     else:
#     888         mode = 'R'
# --> 889     yield TimedAccess(j, mode, i, e.ispace)
#     891 # If a reduction, we got one implicit read
#     892 if e.is_Reduction:
#
# File ~/alif/FWI/.venv/lib/python3.10/site-packages/devito/ir/support/basic.py:217, in TimedAccess.__new__(cls, access, mode, timestamp, ispace)
#     199 class TimedAccess(IterationInstance, AccessMode):
#     201     """
#     202     A TimedAccess ties together an IterationInstance and an AccessMode.
#     203
#    (...)
#     214     on the values of the index functions and the access mode (read, write).
#     215     """
# --> 217     def __new__(cls, access, mode, timestamp, ispace=None):
#     218         obj = super().__new__(cls, access)
#     219         AccessMode.__init__(obj, mode=mode)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
plt.imshow(update.data.T)
plt.colorbar()
plt.show()

print(update.data.min())
# Out:
# -1.0

# %%
import matplotlib.pyplot as plt

plt.plot(misfiti)
plt.title("Graph of Misfit vs Iteration")
plt.xlabel("Iteration")
plt.ylabel('Misfit')
plt.show()

# %%
xmin = (origin[0]*spacing[0])/1000
zmin = (origin[1]*spacing[1])/1000
xmax = (origin[0]*spacing[0] + shape[0]*spacing[0])/1000
zmax = (origin[1]*spacing[1] + shape[1]*spacing[1])/1000
plt.imshow(model0.vp.data[nboundary:nboundary+shape[0], nboundary:nboundary+shape[1]].T, extent=[xmin, xmax, zmax, zmin], cmap='jet', vmin=1.5, vmax=5.0)
plt.colorbar()
plt.xlabel("X (km)")
plt.ylabel("Z (km)")
plt.show()

# %%
ibest = 0
min_misfit= 9999
for i in range(len(misfiti)):
    if misfiti[i]<min_misfit:
        min_misfit = misfiti[i]
        ibest = i
xmin = (origin[0]*spacing[0])/1000
zmin = (origin[1]*spacing[1])/1000
xmax = (origin[0]*spacing[0] + shape[0]*spacing[0])/1000
zmax = (origin[1]*spacing[1] + shape[1]*spacing[1])/1000
plt.imshow(modeli[ibest].vp.data[nboundary:nboundary+shape[0], nboundary:nboundary+shape[1]].T, extent=[xmin, xmax, zmax, zmin], cmap='jet', vmin=1.5, vmax=5.0)
plt.colorbar()
plt.xlabel("X (km)")
plt.ylabel("Z (km)")
plt.show()

# %%
xmin = (origin[0]*spacing[0])/1000
zmin = (origin[1]*spacing[1])/1000
xmax = (origin[0]*spacing[0] + shape[0]*spacing[0])/1000
zmax = (origin[1]*spacing[1] + shape[1]*spacing[1])/1000
plt.imshow(model.vp.data[nboundary:nboundary+shape[0], nboundary:nboundary+shape[1]].T, extent=[xmin, xmax, zmax, zmin], cmap='jet', vmin=1.5, vmax=5.0)
plt.colorbar()
plt.xlabel("X (km)")
plt.ylabel("Z (km)")
plt.show()

# %%
selisih_model = Model(vp=vp0, origin=origin, shape=shape, spacing=spacing,
              space_order=2, nbl=nboundary, bcs="damp", grid = model.grid)
selisih_model.vp.data[:] = modeli[ibest].vp.data[:] - model0.vp.data[:]
xmin = (origin[0]*spacing[0])/1000
zmin = (origin[1]*spacing[1])/1000
xmax = (origin[0]*spacing[0] + shape[0]*spacing[0])/1000
zmax = (origin[1]*spacing[1] + shape[1]*spacing[1])/1000
plt.imshow(selisih_model.vp.data[nboundary:nboundary+shape[0], nboundary:nboundary+shape[1]].T, extent=[xmin, xmax, zmax, zmin], cmap='jet')
plt.colorbar()
plt.xlabel("X (km)")
plt.ylabel("Z (km)")
plt.show()

# %%
selisih_model1 = Model(vp=vp0, origin=origin, shape=shape, spacing=spacing,
              space_order=2, nbl=nboundary, bcs="damp", grid = model.grid)
selisih_model1.vp.data[:] =  model0.vp.data[:]-model.vp.data[:]
xmin = (origin[0]*spacing[0])/1000
zmin = (origin[1]*spacing[1])/1000
xmax = (origin[0]*spacing[0] + shape[0]*spacing[0])/1000
zmax = (origin[1]*spacing[1] + shape[1]*spacing[1])/1000
plt.imshow(selisih_model1.vp.data[nboundary:nboundary+shape[0], nboundary:nboundary+shape[1]].T, extent=[xmin, xmax, zmax, zmin], cmap='jet')
plt.colorbar()
plt.xlabel("X (km)")
plt.ylabel("Z (km)")
plt.show()

# %%
selisih_model2 = Model(vp=vp0, origin=origin, shape=shape, spacing=spacing,
              space_order=2, nbl=nboundary, bcs="damp", grid = model.grid)
selisih_model2.vp.data[:] = modeli[ibest].vp.data[:] - model.vp.data[:]
xmin = (origin[0]*spacing[0])/1000
zmin = (origin[1]*spacing[1])/1000
xmax = (origin[0]*spacing[0] + shape[0]*spacing[0])/1000
zmax = (origin[1]*spacing[1] + shape[1]*spacing[1])/1000
plt.imshow(selisih_model2.vp.data[nboundary:nboundary+shape[0], nboundary:nboundary+shape[1]].T, extent=[xmin, xmax, zmax, zmin], cmap='jet')
plt.colorbar()
plt.xlabel("X (km)")
plt.ylabel("Z (km)")
plt.show()

# %%
import numpy as np

# Contoh data model kecepatan (2D array)
velocity_model = np.array([[4.5, 5.7, 6.0],
                           [5.2, 5.6, 5.8],
                           [6.1, 5.5, 5.9]])

# Threshold kecepatan
threshold = 5.672030575879816

# Mengatur nilai yang lebih besar dari threshold menjadi nilai threshold
velocity_model[velocity_model > threshold] = threshold

# Menampilkan hasil
print(velocity_model)
# Out:
# [[4.5        5.67203058 5.67203058]
#  [5.2        5.6        5.67203058]
#  [5.67203058 5.5        5.67203058]]
