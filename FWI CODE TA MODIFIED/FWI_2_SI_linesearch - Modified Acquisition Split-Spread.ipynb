# %%
import numpy as np
# %matplotlib inline

from devito import configuration
configuration['log-level'] = 'WARNING'

# %%
import scipy.io as sio
from scipy import signal
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from scipy.signal import convolve2d
from scipy.signal import correlate2d
from scipy.signal import fftconvolve
from scipy.signal import convolve
from scipy.signal import correlate

# Contoh membaca file .mat
data = sio.loadmat("vel.mat")
print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'vel', 'nx', 'dx', 'nz'])

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Tue Dec  9 23:54:02 2014',
#  '__version__': '1.0',
#  '__globals__': [],
#  'vel': array([[1500.        , 1500.        , 1500.        , ..., 1500.        ,
#          1500.        , 1500.        ],
#         [1500.        , 1500.        , 1500.        , ..., 1500.        ,
#          1500.        , 1500.        ],
#         [1500.        , 1500.        , 1500.        , ..., 1500.        ,
#          1500.        , 1500.        ],
#         ...,
#         [2487.24926758, 2487.24926758, 2487.24926758, ..., 2399.99951172,
#          2399.99951172, 2399.99951172],
#         [2491.00024414, 2491.00024414, 2491.00024414, ..., 2399.99951172,
#          2399.99951172, 2399.99951172],
#         [2494.75      , 2494.75      , 2494.75      , ..., 2399.99951172,
#          2399.99951172, 2399.99951172]]),
#  'nx': array([[401]], dtype=uint16),
#  'dx': array([[10]], dtype=uint8),
#  'nz': array([[151]], dtype=uint8)}

# %%
# Misalkan velocity model ada di key tertentu, misalnya 'velocity_model':
vp = data['vel'].T[100:300]/1000
#vp0 = np.loadtxt('Vp0 model Padded.txt')
#vp0 = (vp0.T)/1000
vp0 = gaussian_filter(vp, 3) #velocity model intial

print(np.min(vp0))
print(np.max(vp0))

vp0.shape
# Out:
# 1.5
# 3.5281285400099773
# (200, 151)

# %%
nshots = 11  # Number of shots to create gradient from
nreceivers = 120  # Number of receiver locations per shot 
fwi_iterations = 5  # Number of outer FWI iterations

# %%
#NBVAL_IGNORE_OUTPUT
from examples.seismic import Model, plot_velocity, plot_perturbation, Receiver

# Define a physical size
shape = (vp0.shape)  # Number of grid point (nx, nz)
spacing = (10, 10)  # Grid spacing in m. The domain size is now 1km by 1km
origin = (0.,0.)  # What is the location of the top left corner. This is necessary to define
nboundary = 80

model = Model(vp=vp, origin=origin, shape=shape, spacing=spacing,
              space_order=2, nbl=nboundary, bcs="damp")

model0 = Model(vp=vp0, origin=origin, shape=shape, spacing=spacing,
              space_order=2, nbl=nboundary, bcs="damp", grid = model.grid)

plot_velocity(model)
plot_velocity(model0)
plot_perturbation(model0, model)

# %%
#NBVAL_IGNORE_OUTPUT
# Define acquisition geometry: source
from examples.seismic import AcquisitionGeometry, TimeAxis, RickerSource, PointSource, WaveletSource

t0 = 0.
tn = 1300. 
dt = model.critical_dt
time = TimeAxis(start=t0, stop=tn, step=dt)


f0 = 0.010

# First, position source centrally in all dimensions, then set depth
src_coordinates = np.empty((nshots, 2))
src_coordinates[:, 0] = np.linspace(605, 1405, nshots)
src_coordinates[:, 1] = 20.  # Depth is 20m

# %%
geometrys = []

for i in range(nshots):
    # Define acquisition geometry: receivers

    # Initialize receivers for synthetic and imaging data
    rec_coordinates = np.empty((nreceivers, 2))
    rec_coordinates[:, 0] = np.linspace(10+(i*80), 1200+(i*80), nreceivers)
    rec_coordinates[:, 1] = 20.  # Depth is 20m

    # Geometry
    geometry = AcquisitionGeometry(model, rec_coordinates, src_coordinates, t0, tn, f0=f0, src_type='Ricker')
    geometrys.append(geometry)
print(geometrys[0].time_axis)
# Out:
# TimeAxis: start=0, stop=1300.65, step=1.725, num=755

# %%
srct = []

for i in range(nshots):
    src = RickerSource(name='src', grid=model0.grid, f0=f0, time_range=time)
    # First, position source centrally in all dimensions, then set depth
    src.coordinates.data[0, :] = src_coordinates[i, 0]
    src.coordinates.data[0, -1] = 20.  # Depth is 20m
    #src.data[:] *= -1
    srct.append(src)
srct[0].show()
srct[0].data.shape
# Out:
# (755, 1)

# %%
t = np.arange(t0, tn+dt, (dt))
t = t/1000
f0z = f0*1000
t0 = (1/f0z)
st = (1 - (2*(np.pi**2)*(f0z**2)*(t-t0)**2))*(np.exp(-1*(np.pi**2)*(f0z**2)*(t-t0)**2))

wavelet = st

angle = 90
shifted = np.real(np.exp(1j*np.radians(angle)) * signal.hilbert(wavelet))
shifted = np.array([shifted])
shiftedT = shifted.T

srcs = []

for i in range(nshots):
    src = RickerSource(name='src', grid=model0.grid, f0=f0, time_range=time)
    # First, position source centrally in all dimensions, then set depth
    src.coordinates.data[0, :] = src_coordinates[i, 0]
    src.coordinates.data[0, -1] = 20.  # Depth is 20m
    src.data[:] = shiftedT
    src.data[1000:] = 0
    srcs.append(src)
srcs[0].show()
srcs[0].data.shape
# Out:
# (755, 1)

# %%
t = np.arange(t0, tn+dt, (dt))
t = t/1000
f0z = 10
t0 = (1/10)
st = (1 - (2*(np.pi**2)*(f0z**2)*(t-t0)**2))*(np.exp(-1*(np.pi**2)*(f0z**2)*(t-t0)**2))

wavelet = st

angle = 0
shifted = np.real(np.exp(1j*np.radians(angle)) * signal.hilbert(wavelet))
shifted = np.array([shifted])
shiftedT = shifted.T

srcs2 = []

for i in range(nshots):
    src = RickerSource(name='src', grid=model0.grid, f0=f0, time_range=time)
    # First, position source centrally in all dimensions, then set depth
    src.coordinates.data[0, :] = src_coordinates[i, 0]
    src.coordinates.data[0, -1] = 20.  # Depth is 20m
    src.data[:] = shiftedT
    src.data[1000:] = 0
    srcs2.append(src)
srcs2[0].show()
srcs2[0].data.shape
# Out:
# (755, 1)

# %%
#NBVAL_IGNORE_OUTPUT
# Plot acquisition geometry
plot_velocity(model, source=geometrys[0].src_positions,
              receiver=geometrys[0].rec_positions)

# %%
# Mencari indeks geophone terdekat untuk setiap shot
nearest_indices = []
i=0
for shot in geometry.src_positions:
    distances = np.linalg.norm(geometrys[i].rec_positions - shot, axis=1)  # Hitung jarak Euclidean
    nearest_index = np.argmin(distances)  # Cari indeks dengan jarak minimum
    nearest_indices.append(nearest_index)
    i+=1

# %%
print(nearest_indices)
# Out:
# [59, 59, 59, 59, 59, 59, 59, 59, 59, 59, 59]

# %%
from devito import Eq, Operator

# Computes the residual between observed and synthetic data into the residual
def compute_residual(residual, dobs, dsyn, kg):
    if residual.grid.distributor.is_parallel:
        # If we run with MPI, we have to compute the residual via an operator
        # First make sure we can take the difference and that receivers are at the 
        # same position
        assert np.allclose(dobs.coordinates.data[:], dsyn.coordinates.data)
        assert np.allclose(residual.coordinates.data[:], dsyn.coordinates.data)
        # Create a difference operator
        diff_eq = Eq(residual, dsyn.subs({dsyn.dimensions[-1]: residual.dimensions[-1]}) -
                               dobs.subs({dobs.dimensions[-1]: residual.dimensions[-1]}))
        Operator(diff_eq)()
    else:
        # Data ukuran (1920 x 120)
        data_1 = dsyn.data[:]
        data_2 = dobs.data[:]

        # Data ukuran (1920 x 120)
        

        # Pastikan data_2 menjadi array 1D untuk keperluan konvolusi
        filter_data1 = dobs.data[:,kg]
        filter_data2 = dsyn.data[:,kg]


        for i in range(residual.data.shape[1]):
            # Panjang data asli
            len_data1 = len(data_1)

            # Panjang hasil korelasi
            len_full = len(convolve(filter_data1, data_1[:, i], mode='full'))

            # Indeks untuk mengambil nilai tengah
            start = (len_full - len_data1) // 2
            end = start + len_data1
            
            residual.data[:, i] = convolve(data_1[:, i], filter_data1, mode='full')[:len_data1] - convolve(data_2[:, i], filter_data2, mode='full')[:len_data1]
            
         # Data berukuran (1920 x 1)
        
        data_1 = dobs.data[:,kg]

        # Data berukuran (1920 x 120)
        data_2 = residual.data[:]    
        # Menyimpan hasil cross-correlation
        cross_correlations = []
        cross_correlations2 = []
        len_data = len(data_1)
        # Lakukan cross-correlation untuk setiap kolom di data_2
        for i in range(data_2.shape[1]):
            result = correlate(data_2[:, i], data_1, mode='full')[len_data-1:]
            result2 = correlate(data_2[:,i], dobs.data[:,i], mode='full')[len_data-1:]
            cross_correlations.append(result)
            cross_correlations2.append(result2)
        residual.data[:] = np.array(cross_correlations).T
        
        #cross_correlations2 = np.array(cross_correlations2)
        #tracekg = np.sum(cross_correlations2, axis=0)
        
        #residual.data[:, kg] *= 0
        
        
        #residual.data[:] = ((residual.data[:] - residual.data[:].min())/(residual.data[:].max()-residual.data[:].min()))*((dobs.data[:].max()-dobs.data.min())+dobs.data.min())
    return residual

# %%
def misfit(vp_in):
    objective = 0.
    for i in range(nshots):
        # Compute synthetic data with forward operator 
        from examples.seismic.acoustic import AcousticWaveSolver

        solver = AcousticWaveSolver(model, geometrys[i], space_order=2)
        
        # Create placeholders for the data residual and data
        residual = Receiver(name='residual', grid=model0.grid,
                            time_range=geometrys[i].time_axis, 
                            coordinates=geometrys[i].rec_positions)
        d_obs = Receiver(name='d_obs', grid=model.grid,
                         time_range=geometrys[i].time_axis, 
                         coordinates=geometrys[i].rec_positions)
        d_syn = Receiver(name='d_syn', grid=model0.grid,
                        time_range=geometrys[i].time_axis, 
                        coordinates=geometrys[i].rec_positions)
        # Update source location
        #geometry.src_positions[0, :] = src_coordinates[i, :]

        # Generate synthetic data from true model
        _, _, _ = solver.forward(vp=model.vp, src=srcs[i], rec=d_obs)

        # Compute smooth data and full forward wavefield u0
        _, _, _ = solver.forward(vp=vp_in.vp, src=srcs2[i], rec=d_syn)

        # Compute gradient from data residual and update objective function 
        compute_residual(residual, d_obs, d_syn, nearest_indices[i])
        objective += 0.5*norm(residual)**2
    return objective

# %%
def linesearch(a, b, l, vp_in, ff,  g):
    from copy import deepcopy
    from devito import Function, TimeFunction, norm
    vp2 = deepcopy(vp_in)
    vp2.vp.data[:] = vp_in.vp.data[:] + l*(g.data[:]/1000)
    gnorm = a*l*norm(g)
    ff2 = misfit(vp2)
    ni = 1
    while (ff2 > ff - gnorm):
        l = b*l
        vp2.vp.data[:] = vp_in.vp.data[:] + l*(g.data[:]/1000)
        ff2 = misfit(vp2)
        gnorm = a*l*norm(g)
        print(ni)
        ni+=1
        if l < 1e-5:
            break
    return l

# %%
def fletcherreeves(g0, g1):
  bi = -(np.linalg.norm(g1.data[:], ord=2)/np.linalg.norm(g0.data[:], ord=2))
  g1.data[:] -= bi*g0.data[:]
  return g1

# %%
# Create FWI gradient kernel 
from devito import Function, TimeFunction, norm
from examples.seismic import Receiver, plot_shotrecord

import scipy
def fwi_gradient(vp_in):    
    # Create symbols to hold the gradient
    grad = Function(name="grad", grid=model.grid)
    
    objective = 0.
    for i in range(nshots):
        # Compute synthetic data with forward operator 
        from examples.seismic.acoustic import AcousticWaveSolver

        solver = AcousticWaveSolver(model, geometrys[i], space_order=2)
        
        # Create placeholders for the data residual and data
        residual = Receiver(name='residual', grid=model.grid,
                            time_range=geometrys[i].time_axis, 
                            coordinates=geometrys[i].rec_positions)
        d_obs = Receiver(name='d_obs', grid=model.grid,
                         time_range=geometrys[i].time_axis, 
                         coordinates=geometrys[i].rec_positions)
        d_syn = Receiver(name='d_syn', grid=model.grid,
                        time_range=geometrys[i].time_axis, 
                        coordinates=geometrys[i].rec_positions)

        
        # Update source location
        #geometry.src_positions[0, :] = src_coordinates[i, :]

        # Generate synthetic data from true model
        _, _, _ = solver.forward(vp=model.vp, src=srcs[i], rec=d_obs)

        # Compute smooth data and full forward wavefield u0
        _, u0, _ = solver.forward(vp=vp_in, save=True, src=srcs2[i], rec=d_syn)
        
        #plot_shotrecord(d_syn.data[:], model0, t0,tn)
        # Compute gradient from data residual and update objective function 
        compute_residual(residual, d_obs, d_syn, nearest_indices[i])
        
        #plot_shotrecord(residual.data, model, t0, tn)
        
        objective += .5*norm(residual)**2
        
        #=plot_shotrecord(residual.data, model, t0, tn)
        solver.gradient(rec=residual, u=u0, vp=vp_in, grad=grad)
        
        
    gradNormalized = Function(name="gradNormalized", grid=model.grid)
    grad.data[:] *= watermute.data[:]
    #grad.data[:] *= modelpadmute.data[:]
    #Normalisasi ke rentang [-1, 1]
    gradNormalized.data[:] = (grad.data)/np.abs(grad.data[:]).max()
    
        

    return objective, gradNormalized

# %%
waterheight = 27
watermute = Function(name="watermute", grid=model.grid)
watermute.data[:,nboundary+waterheight:] += 1

# %%
modelpad = 30
modelpadmute = Function(name="modelpadmute", grid=model.grid)
modelpadmute.data[nboundary+modelpad:,:] += 1
modelpadmute.data[280-(nboundary+modelpad):280,:] = 0

# %%
modeli =[]
misfiti = []
gradi = []

update_model = Model(vp=vp0, origin=origin, shape=shape, spacing=spacing,
              space_order=2, nbl=nboundary, bcs="damp", grid = model.grid)
#plot_velocity(update_model)

modeli.append(update_model)

fwi_iterations = 100  # Number of outer FWI iteration
fwi_index = 0

ff, update = fwi_gradient(update_model.vp)

misfiti.append(ff)
gradi.append(update)
    
print(f"iterasi ke-{0} : {ff}")
    
a = 0.25
b = 0.5
L = 100

L = linesearch(a, b, L, update_model, ff,  update)

    
update_model.vp.data[:] += (L*update.data[:]/1000)
    
    # Threshold kecepatan
    #threshold = 5.672030575879816

    # Mengatur nilai yang lebih besar dari threshold menjadi nilai threshold
    #update_model.vp.data[update_model.vp.data > threshold] = threshold
    
    
modeli.append(update_model)

update0 = update

for i in range(fwi_iterations-1):
    ff, update = fwi_gradient(update_model.vp)

    update = fletcherreeves(update0, update)

    misfiti.append(ff)
    gradi.append(update)
    
    print(f"iterasi ke-{i+1} : {ff}")
    
    a = 0.25
    b = 0.5
    L = 100

    L = linesearch(a, b, L, update_model, ff,  update)

    
    update_model.vp.data[:] += (L*update.data[:]/1000)
    
    # Threshold kecepatan
    #threshold = 5.672030575879816

    # Mengatur nilai yang lebih besar dari threshold menjadi nilai threshold
    #update_model.vp.data[update_model.vp.data > threshold] = threshold
    
    
    modeli.append(update_model)
    
    #if i >= 2 :
        #if (np.abs(ff-misfiti[i-1]))<1e-3:
            #break
    fwi_index+=1
    update0 = update

ff, update = fwi_gradient(update_model.vp)
misfiti.append(ff)
gradi.append(update)

print(f"iterasi ke-{fwi_index} : {ff}")
# Out:
# iterasi ke-0 : 1757200680469313.0
# iterasi ke-1 : 1052634402884515.5
# iterasi ke-2 : 664811280210596.8
# iterasi ke-3 : 443350862355307.25
# iterasi ke-4 : 405046986787475.1
# iterasi ke-5 : 292237371828875.6
# 1
# iterasi ke-6 : 238220308430685.44
# 1
# iterasi ke-7 : 212444887496851.8
# iterasi ke-8 : 211004158768985.4
# 1
# iterasi ke-9 : 165674670010177.06
# 1
# 2
# iterasi ke-10 : 149049257372458.97
# 1
# 2
# iterasi ke-11 : 138023708594654.38
# 1
# 2
# iterasi ke-12 : 128029344644013.4
# 1
# 2
# iterasi ke-13 : 122769838752530.12
# 1
# 2
# iterasi ke-14 : 118417493874056.72
# 1
# 2
# 3
# iterasi ke-15 : 115023497749536.72
# 1
# 2
# 3
# iterasi ke-16 : 112980438471862.03
# 1
# 2
# iterasi ke-17 : 112170765018476.06
# 1
# 2
# iterasi ke-18 : 109361579620122.02
# 1
# 2
# iterasi ke-19 : 108183626598292.97
# 1
# 2
# iterasi ke-20 : 103712654885742.97
# 1
# 2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/devito/tools/memoization.py:90, in memoized_meth.__call__(self, *args, **kw)
#      89 try:
# ---> 90     res = cache[key]
#      91 except KeyError:
#
# KeyError: (<function AcousticWaveSolver.op_grad at 0x7f0f4233a480>, (), frozenset())
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[233], line 42
#      39 update0 = update
#      41 for i in range(fwi_iterations-1):
# ---> 42     ff, update = fwi_gradient(update_model.vp)
#      44     update = fletcherreeves(update0, update)
#      46     misfiti.append(ff)
#
# Cell In[210], line 47, in fwi_gradient(vp_in)
#      44     objective += .5*norm(residual)**2
#      46     #=plot_shotrecord(residual.data, model, t0, tn)
# ---> 47     solver.gradient(rec=residual, u=u0, vp=vp_in, grad=grad)
#      50 gradNormalized = Function(name="gradNormalized", grid=model.grid)
#      51 grad.data[:] *= watermute.data[:]
#
# File ~/anaconda3/lib/python3.12/site-packages/examples/seismic/acoustic/wavesolver.py:212, in AcousticWaveSolver.jacobian_adjoint(self, rec, u, src, v, grad, model, checkpointing, **kwargs)
#     210     summary = wrp.apply_reverse()
#     211 else:
# --> 212     summary = self.op_grad().apply(rec=rec, grad=grad, v=v, u=u, dt=dt,
#     213                                    **kwargs)
#     214 return grad, summary
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/tools/memoization.py:92, in memoized_meth.__call__(self, *args, **kw)
#      90     res = cache[key]
#      91 except KeyError:
# ---> 92     res = cache[key] = self.func(*args, **kw)
#      93 return res
#
# File ~/anaconda3/lib/python3.12/site-packages/examples/seismic/acoustic/wavesolver.py:63, in AcousticWaveSolver.op_grad(self, save)
#      60 @memoized_meth
#      61 def op_grad(self, save=True):
#      62     """Cached operator for gradient runs"""
# ---> 63     return GradientOperator(self.model, save=save, geometry=self.geometry,
#      64                             kernel=self.kernel, space_order=self.space_order,
#      65                             **self._kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/examples/seismic/acoustic/operators.py:231, in GradientOperator(model, geometry, space_order, save, kernel, **kwargs)
#     228 receivers = rec.inject(field=v.backward, expr=rec * s**2 / m)
#     230 # Substitute spacing terms to reduce flops
# --> 231 return Operator(eqn + receivers + [gradient_update], subs=model.spacing_map,
#     232                 name='Gradient', **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/operator/operator.py:165, in Operator.__new__(cls, expressions, **kwargs)
#     163 # Lower to a JIT-compilable object
#     164 with timed_region('op-compile') as r:
# --> 165     op = cls._build(expressions, **kwargs)
#     166 op._profiler.py_timers.update(r.timings)
#     168 # Emit info about how long it took to perform the lowering
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/operator/operator.py:197, in Operator._build(cls, expressions, **kwargs)
#     194 profiler = create_profile('timers')
#     196 # Lower the input expressions into an IET
# --> 197 irs, byproduct = cls._lower(expressions, profiler=profiler, **kwargs)
#     199 # Make it an actual Operator
#     200 op = Callable.__new__(cls, **irs.iet.args)
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/operator/operator.py:280, in Operator._lower(cls, expressions, **kwargs)
#     277 uiet = cls._lower_uiet(stree, **kwargs)
#     279 # unbounded IET -> IET
# --> 280 iet, byproduct = cls._lower_iet(uiet, **kwargs)
#     282 return IRs(expressions, clusters, stree, uiet, iet), byproduct
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/tools/timing.py:76, in timed_pass.__call__(self, *args, **kwargs)
#      73 stack.append(frame)
#      75 tic = time()
# ---> 76 retval = self.func(*args, **kwargs)
#      77 toc = time()
#      79 for f in stack:
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/operator/operator.py:474, in Operator._lower_iet(cls, uiet, profiler, **kwargs)
#     472 # Lower IET to a target-specific IET
#     473 graph = Graph(iet, **kwargs)
# --> 474 graph = cls._specialize_iet(graph, **kwargs)
#     476 # Instrument the IET for C-level profiling
#     477 # Note: this is postponed until after _specialize_iet because during
#     478 # specialization further Sections may be introduced
#     479 cls._Target.instrument(graph, profiler=profiler, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/tools/timing.py:76, in timed_pass.__call__(self, *args, **kwargs)
#      73 stack.append(frame)
#      75 tic = time()
# ---> 76 retval = self.func(*args, **kwargs)
#      77 toc = time()
#      79 for f in stack:
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/core/cpu.py:198, in Cpu64AdvOperator._specialize_iet(cls, graph, **kwargs)
#     195 avoid_denormals(graph, **kwargs)
#     197 # Distributed-memory parallelism
# --> 198 mpiize(graph, **kwargs)
#     200 # Lower BlockDimensions so that blocks of arbitrary shape may be used
#     201 relax_incr_dimensions(graph, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/passes/iet/mpi.py:364, in mpiize(graph, **kwargs)
#     361 options = kwargs['options']
#     363 if options['opt-comms']:
# --> 364     optimize_halospots(graph, **kwargs)
#     366 mpimode = options['mpi']
#     367 if mpimode:
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/passes/iet/engine.py:197, in iet_pass.<locals>.wrapper(*args, **kwargs)
#     194 try:
#     195     # Pure function case
#     196     graph, = args
# --> 197     return maybe_timed(call(graph), func.__name__)(func, **kwargs)
#     198 except ValueError:
#     199     # Instance method case
#     200     self, graph = args
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/tools/timing.py:76, in timed_pass.__call__(self, *args, **kwargs)
#      73 stack.append(frame)
#      75 tic = time()
# ---> 76 retval = self.func(*args, **kwargs)
#      77 toc = time()
#      79 for f in stack:
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/passes/iet/engine.py:118, in Graph.apply(self, func, **kwargs)
#     116 efuncs = dict(self.efuncs)
#     117 for i in dag.topological_sort():
# --> 118     efunc, metadata = func(efuncs[i], **kwargs)
#     120     self.includes.extend(as_tuple(metadata.get('includes')))
#     121     self.headers.extend(as_tuple(metadata.get('headers')))
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/passes/iet/mpi.py:27, in optimize_halospots(iet, **kwargs)
#      25 iet = _drop_halospots(iet)
#      26 iet = _hoist_halospots(iet)
# ---> 27 iet = _merge_halospots(iet)
#      28 iet = _drop_if_unwritten(iet, **kwargs)
#      29 iet = _mark_overlappable(iet)
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/passes/iet/mpi.py:190, in _merge_halospots(iet)
#     187     continue
#     189 for f, v in hs1.fmapper.items():
# --> 190     for dep in scope.d_flow.project(f):
#     191         if not any(r(dep, hs1, v.loc_indices) for r in rules):
#     192             break
#
# File ~/anaconda3/lib/python3.12/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/ir/support/basic.py:1085, in Scope.d_flow(self)
#    1082 @cached_property
#    1083 def d_flow(self):
#    1084     """Flow (or "read-after-write") dependences."""
# -> 1085     return DependenceGroup(self.d_flow_gen())
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/ir/support/basic.py:1066, in Scope.d_flow_gen(self)
#    1063 if any(not rule(w, r) for rule in self.rules):
#    1064     continue
# -> 1066 dependence = Dependence(w, r)
#    1068 if dependence.is_imaginary:
#    1069     continue
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/ir/support/basic.py:512, in Relation.__init__(self, source, sink)
#     510 def __init__(self, source, sink):
#     511     assert isinstance(source, TimedAccess) and isinstance(sink, TimedAccess)
# --> 512     assert source.function == sink.function
#     513     self.source = source
#     514     self.sink = sink
#
# File ~/anaconda3/lib/python3.12/site-packages/devito/types/basic.py:920, in AbstractFunction.__eq__(self, other)
#     917 def _pretty(self, printer, **kwargs):
#     918     return printer._print_Function(self, func_name=self.name)
# --> 920 def __eq__(self, other):
#     921     try:
#     922         return (self.function is other.function and
#     923                 self.indices == other.indices and
#     924                 other.is_AbstractFunction)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
plt.imshow(gradi[5].data.T)
plt.colorbar()
plt.show()

print(update.data.min())
# Out:
# -0.7330232

# %%
import matplotlib.pyplot as plt

plt.plot(misfiti)
plt.title("Graph of Misfit vs Iteration")
plt.xlabel("Iteration")
plt.ylabel('Misfit')
plt.show()

# %%
xmin = (origin[0]*spacing[0])/1000
zmin = (origin[1]*spacing[1])/1000
xmax = (origin[0]*spacing[0] + shape[0]*spacing[0])/1000
zmax = (origin[1]*spacing[1] + shape[1]*spacing[1])/1000
plt.imshow(model0.vp.data[nboundary:nboundary+shape[0], nboundary:nboundary+shape[1]].T, extent=[xmin, xmax, zmax, zmin], cmap='jet', vmin=1.5, vmax=3.5)
plt.colorbar()
plt.xlabel("X (km)")
plt.ylabel("Z (km)")
plt.show()

# %%
ibest = 0
min_misfit= 9999
for i in range(len(misfiti)):
    if misfiti[i]<min_misfit:
        min_misfit = misfiti[i]
        ibest = i
xmin = (origin[0]*spacing[0])/1000
zmin = (origin[1]*spacing[1])/1000
xmax = (origin[0]*spacing[0] + shape[0]*spacing[0])/1000
zmax = (origin[1]*spacing[1] + shape[1]*spacing[1])/1000
plt.imshow(modeli[ibest].vp.data[nboundary:nboundary+shape[0], nboundary:nboundary+shape[1]].T, extent=[xmin, xmax, zmax, zmin], cmap='jet', vmin=1.5, vmax=3.5)
plt.colorbar()
plt.xlabel("X (km)")
plt.ylabel("Z (km)")
plt.show()

# %%
xmin = (origin[0]*spacing[0])/1000
zmin = (origin[1]*spacing[1])/1000
xmax = (origin[0]*spacing[0] + shape[0]*spacing[0])/1000
zmax = (origin[1]*spacing[1] + shape[1]*spacing[1])/1000
plt.imshow(model.vp.data[nboundary+1:nboundary+shape[0]+1, nboundary+1:nboundary+shape[1]+1].T, extent=[xmin, xmax, zmax, zmin], cmap='jet', vmin=1.5, vmax=3.5)
plt.colorbar()
plt.xlabel("X (km)")
plt.ylabel("Z (km)")
plt.show()
print(shape[1])
# Out:
# 151

# %%
xmin = (origin[0]*spacing[0])/1000
zmin = (origin[1]*spacing[1])/1000
xmax = (origin[0]*spacing[0] + shape[0]*spacing[0])/1000
zmax = (origin[1]*spacing[1] + shape[1]*spacing[1])/1000
plt.imshow(model.vp.data[nboundary+1:nboundary+shape[0]+1, nboundary+1:nboundary+shape[1]+1].T, extent=[xmin, xmax, zmax, zmin], cmap='jet', vmin=1.5, vmax=3.5)
plt.colorbar()
plt.xlabel("X (km)")
plt.ylabel("Z (km)")
plt.show()
print(shape[1])
# Out:
# 151

# %%
selisih_model = Model(vp=vp0, origin=origin, shape=shape, spacing=spacing,
              space_order=2, nbl=nboundary, bcs="damp", grid = model.grid)
selisih_model.vp.data[:] = modeli[ibest].vp.data[:] - model0.vp.data[:]
xmin = (origin[0]*spacing[0])/1000
zmin = (origin[1]*spacing[1])/1000
xmax = (origin[0]*spacing[0] + shape[0]*spacing[0])/1000
zmax = (origin[1]*spacing[1] + shape[1]*spacing[1])/1000
plt.imshow(selisih_model.vp.data[nboundary:nboundary+shape[0], nboundary:nboundary+shape[1]].T, extent=[xmin, xmax, zmax, zmin], cmap='jet')
plt.colorbar()
plt.xlabel("X (km)")
plt.ylabel("Z (km)")
plt.show()

# %%
selisih_model1 = Model(vp=vp0, origin=origin, shape=shape, spacing=spacing,
              space_order=2, nbl=nboundary, bcs="damp", grid = model.grid)
selisih_model1.vp.data[:] =  model0.vp.data[:]-model.vp.data[:]
xmin = (origin[0]*spacing[0])/1000
zmin = (origin[1]*spacing[1])/1000
xmax = (origin[0]*spacing[0] + shape[0]*spacing[0])/1000
zmax = (origin[1]*spacing[1] + shape[1]*spacing[1])/1000
plt.imshow(selisih_model1.vp.data[nboundary:nboundary+shape[0], nboundary:nboundary+shape[1]].T, extent=[xmin, xmax, zmax, zmin], cmap='jet')
plt.colorbar()
plt.xlabel("X (km)")
plt.ylabel("Z (km)")
plt.show()

# %%
selisih_model2 = Model(vp=vp0, origin=origin, shape=shape, spacing=spacing,
              space_order=2, nbl=nboundary, bcs="damp", grid = model.grid)
selisih_model2.vp.data[:] = modeli[ibest].vp.data[:] - model.vp.data[:]
xmin = (origin[0]*spacing[0])/1000
zmin = (origin[1]*spacing[1])/1000
xmax = (origin[0]*spacing[0] + shape[0]*spacing[0])/1000
zmax = (origin[1]*spacing[1] + shape[1]*spacing[1])/1000
plt.imshow(selisih_model2.vp.data[nboundary:nboundary+shape[0], nboundary:nboundary+shape[1]].T, extent=[xmin, xmax, zmax, zmin], cmap='jet')
plt.colorbar()
plt.xlabel("X (km)")
plt.ylabel("Z (km)")
plt.show()

# %%
import numpy as np

# Contoh data model kecepatan (2D array)
velocity_model = np.array([[4.5, 5.7, 6.0],
                           [5.2, 5.6, 5.8],
                           [6.1, 5.5, 5.9]])

# Threshold kecepatan
threshold = 5.672030575879816

# Mengatur nilai yang lebih besar dari threshold menjadi nilai threshold
velocity_model[velocity_model > threshold] = threshold

# Menampilkan hasil
print(velocity_model)
# Out:
# [[4.5        5.67203058 5.67203058]
#  [5.2        5.6        5.67203058]
#  [5.67203058 5.5        5.67203058]]
